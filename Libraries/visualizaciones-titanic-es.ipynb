# %% [markdown]
# # Visualizaciones de Datos con Librerías de Python
# Katlyn Mackness <br>
# 17/07/24 - Updated 20/02/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('titanic.csv')

# %%
# El Histograma de frecuencias para la variable edad 
fig, ax = plt.subplots()
ax.hist(df["Age"])
ax.set_xlabel("Edad")
ax.set_ylabel("# de pasajeros")
plt.show()

# %%
# Descargar figura
fig.savefig("edad_pasajeros_hist.jpg")

# %%
# El diagrama de caja para la variable edad
fig, ax = plt.subplots()
ax.boxplot([df["Age"]])
ax.set_xticklabels(["Pasajeros"])
ax.set_ylabel("Edad de pasajero")
plt.show()

# %%
# Descargar figura
fig.savefig("edad_pasajeros_box.jpg")

# %%
# Un gráfico que muestre el número de pasajeros de cada clase (Pclass)
df = pd.read_csv('titanic.csv', index_col="Pclass")

# %%
# Visualización de pasajeros por clase
fig, ax = plt.subplots()
ax.hist(df.index, bins = [1, 2, 3, 4], )
ax.set_title('Numero de pasajeros por clase') 
ax.set_xticks([1,2,3])
ax.set_xlabel("Clase")
ax.set_ylabel("# de pasajeros")
plt.show()

# %%
# Descargar figura
fig.savefig("pasajeros_clase_hist.jpg")
